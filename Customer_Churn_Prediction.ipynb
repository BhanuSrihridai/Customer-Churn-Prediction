# %% [markdown]
# <a href="https://colab.research.google.com/github/BhanuSrihridai/Customer-Churn-Prediction/blob/Current-Branch/Customer_Churn_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Glimpse of the data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("customer churn.csv")
data.head()
# Out:
#    CustomerID        Name   Age  Gender     Location  \
# 0           1  Customer_1  63.0    Male  Los Angeles
# 1           2  Customer_2  62.0  Female     New York
# 2           3  Customer_3  24.0  Female  Los Angeles
# 3           4  Customer_4  36.0  Female        Miami
# 4           5  Customer_5  46.0  Female        Miami
#
#    Subscription_Length_Months  Monthly_Bill  Total_Usage_GB  Churn
# 0                        17.0         73.36           236.0    0.0
# 1                         1.0         48.76           172.0    0.0
# 2                         5.0         85.47           460.0    0.0
# 3                         3.0         97.94           297.0    1.0
# 4                        19.0         58.14           266.0    0.0

# %%
data.sample(10).style.bar(cmap='hsv',height=65,width=70) # Adding internal bar charts to numerical columns for a sample of the data
# Out:
# <style type="text/css">
# #T_69902_row0_col0, #T_69902_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #003fff 44.5%, transparent 44.5%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #00afff 39.2%, transparent 39.2%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row0_col5, #T_69902_row2_col5, #T_69902_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bd 62.2%, transparent 62.2%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #00ff9d 31.0%, transparent 31.0%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #00f6ff 35.9%, transparent 35.9%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row0_col8, #T_69902_row1_col8, #T_69902_row2_col8, #T_69902_row3_col8, #T_69902_row5_col8 {
#   width: 10em;
# }
# #T_69902_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6a00 5.0%, transparent 5.0%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #00ff10 24.4%, transparent 24.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff006b 66.1%, transparent 66.1%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #ad00ff 55.3%, transparent 55.3%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row1_col7, #T_69902_row5_col5, #T_69902_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #00b5ff 38.9%, transparent 38.9%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ffb700 8.5%, transparent 8.5%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fc00f5 59.4%, transparent 59.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00e7 60.4%, transparent 60.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #0057ff 43.4%, transparent 43.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #00eaff 36.4%, transparent 36.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #00ff80 29.7%, transparent 29.7%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #0010ff 46.7%, transparent 46.7%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #00ff39 26.3%, transparent 26.3%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #006eff 42.3%, transparent 42.3%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #1f00ff 48.7%, transparent 48.7%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row4_col2, #T_69902_row4_col8, #T_69902_row6_col6, #T_69902_row6_col7, #T_69902_row6_col8, #T_69902_row7_col0, #T_69902_row7_col8, #T_69902_row8_col5, #T_69902_row8_col8, #T_69902_row9_col5, #T_69902_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff0018 70.0%, transparent 70.0%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #9b00ff 54.4%, transparent 54.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #00ff80 29.8%, transparent 29.8%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff0071 65.7%, transparent 65.7%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff0024 69.4%, transparent 69.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #00ffbb 32.4%, transparent 32.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #00fffc 35.4%, transparent 35.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #25ff00 22.0%, transparent 22.0%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #1f00ff 48.8%, transparent 48.8%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff002a 68.9%, transparent 68.9%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00a0 63.6%, transparent 63.6%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00c3 62.0%, transparent 62.0%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #49ff00 20.4%, transparent 20.4%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00b7 62.6%, transparent 62.6%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #0800ff 47.6%, transparent 47.6%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d7ff00 13.8%, transparent 13.8%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff5900 4.2%, transparent 4.2%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00cf 61.5%, transparent 61.5%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #00dfff 37.0%, transparent 37.0%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# #T_69902_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #fa00f9 59.2%, transparent 59.2%) no-repeat center;
#   background-size: 100% 65.0%;
# }
# </style>
# <table id="T_69902" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69902_level0_col0" class="col_heading level0 col0" >CustomerID</th>
#       <th id="T_69902_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_69902_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_69902_level0_col3" class="col_heading level0 col3" >Gender</th>
#       <th id="T_69902_level0_col4" class="col_heading level0 col4" >Location</th>
#       <th id="T_69902_level0_col5" class="col_heading level0 col5" >Subscription_Length_Months</th>
#       <th id="T_69902_level0_col6" class="col_heading level0 col6" >Monthly_Bill</th>
#       <th id="T_69902_level0_col7" class="col_heading level0 col7" >Total_Usage_GB</th>
#       <th id="T_69902_level0_col8" class="col_heading level0 col8" >Churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69902_level0_row0" class="row_heading level0 row0" >62736</th>
#       <td id="T_69902_row0_col0" class="data row0 col0" >62737</td>
#       <td id="T_69902_row0_col1" class="data row0 col1" >Customer_62737</td>
#       <td id="T_69902_row0_col2" class="data row0 col2" >37</td>
#       <td id="T_69902_row0_col3" class="data row0

# %%
data.shape
# Out:
# (100000, 9)

# %%
data.describe()
# Out:
#           CustomerID            Age  Subscription_Length_Months  \
# count  100000.000000  100000.000000               100000.000000
# mean    50000.500000      44.027020                   12.490100
# std     28867.657797      15.280283                    6.926461
# min         1.000000      18.000000                    1.000000
# 25%     25000.750000      31.000000                    6.000000
# 50%     50000.500000      44.000000                   12.000000
# 75%     75000.250000      57.000000                   19.000000
# max    100000.000000      70.000000                   24.000000
#
#         Monthly_Bill  Total_Usage_GB          Churn
# count  100000.000000   100000.000000  100000.000000
# mean       65.053197      274.393650       0.497790
# std        20.230696      130.463063       0.499998
# min        30.000000       50.000000       0.000000
# 25%        47.540000      161.000000       0.000000
# 50%        65.010000      274.000000       0.000000
# 75%        82.640000      387.000000       1.000000
# max       100.000000      500.000000       1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CustomerID                  100000 non-null  int64
#  1   Name                        100000 non-null  object
#  2   Age                         100000 non-null  int64
#  3   Gender                      100000 non-null  object
#  4   Location                    100000 non-null  object
#  5   Subscription_Length_Months  100000 non-null  int64
#  6   Monthly_Bill                100000 non-null  float64
#  7   Total_Usage_GB              100000 non-null  int64
#  8   Churn                       100000 non-null  int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 6.9+ MB

# %% [markdown]
# There aren't missing values.

# %%
data.dtypes
# Out:
# CustomerID                      int64
# Name                           object
# Age                             int64
# Gender                         object
# Location                       object
# Subscription_Length_Months      int64
# Monthly_Bill                  float64
# Total_Usage_GB                  int64
# Churn                           int64
# dtype: object

# %%
cat_cols=data.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Name', 'Gender', 'Location'], dtype='object')

# %%
for column in cat_cols[1:]:
  unique_types=data[column].value_counts()
  print("\nIndividual Counts of ",column,":\n",unique_types)
# Out:
# Individual Counts of  Gender :
#  Female    50216
# Male      49784
# Name: Gender, dtype: int64
#
# Individual Counts of  Location :
#  Houston        20157
# Los Angeles    20041
# Miami          20031
# Chicago        19958
# New York       19813
# Name: Location, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(9,3))

axes=sns.countplot(data=data,y='Churn',width=0.5,saturation=1,palette='rocket')
plt.title('Count of Churn')
plt.ylabel('Count')

axes.bar_label(axes.containers[0],color='white',padding=-40,fontweight='bold')                    # Setting the barlables, so that the count can be seen on the bars
axes.spines[['right','top','bottom']].set_visible(False)                                          # Removing the chart junk like boarders
axes.xaxis.set_visible(False)

# %% [markdown]
# Data is balanced. No need to implement data balancing techniques.

# %% [markdown]
# # **Data Cleaning & EDA**

# %% [markdown]
# As the values of columns 'Name' and 'Customer ID' are unique, we can drop them.

# %%
data=data.drop(['CustomerID','Name'],axis=1)

# %%
data.head()
# Out:
#    Age  Gender     Location  Subscription_Length_Months  Monthly_Bill  \
# 0   63    Male  Los Angeles                          17         73.36
# 1   62  Female     New York                           1         48.76
# 2   24  Female  Los Angeles                           5         85.47
# 3   36  Female        Miami                           3         97.94
# 4   46  Female        Miami                          19         58.14
#
#    Total_Usage_GB  Churn
# 0             236      0
# 1             172      0
# 2             460      0
# 3             297      1
# 4             266      0

# %% [markdown]
# ### **1. Age column**

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(9,3))
sns.boxplot(data=data,x='Age',palette='rocket')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# There are no outliers.

# %%
fig,axes=plt.subplots(1,2,figsize=(25,7))

sns.histplot(data=data,x=data['Age'],hue='Churn',palette='seismic_r',binwidth=2,kde=True,ax=axes[0]).set_title("Histogram of Age Column",fontweight='bold',fontsize=20)
sns.histplot(data=data,x=data['Age'],hue='Churn',palette='mako',binwidth=2,kde=True,ax=axes[1],multiple='fill',stat='probability').set_title("Histogram of Probability of Churn in Age",fontweight='bold',fontsize=20 )
# Out:
# Text(0.5, 1.0, 'Histogram of Probability of Churn in Age')

# %% [markdown]
# The probability of churn is almost same among all age groups.

# %%
sns.scatterplot(data=data,x='Age',y='Subscription_Length_Months',palette='rocket',hue='Churn')
# Out:
# <Axes: xlabel='Age', ylabel='Subscription_Length_Months'>

# %%
sns.jointplot(data=data,x='Age',y='Subscription_Length_Months',palette='hsv',hue='Churn',kind='kde')

# %%
data_group=data.groupby('Age').mean()
data_group
# Out:
# <ipython-input-19-6a84120c61e4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_group=data.groupby('Age').mean()
#      Subscription_Length_Months  Monthly_Bill  Total_Usage_GB     Churn
# Age
# 18                    12.564981     65.601762      276.410549  0.510604
# 19                    12.426069     64.132705      271.636270  0.480680
# 20                    12.457582     64.802063      274.128314  0.494698
# 21                    12.363205     64.689215      267.773326  0.489721
# 22                    12.579183     64.302311      274.567991  0.486849
# 23                    12.491256     64.782777      274.014308  0.491786
# 24                    12.296908     65.687271      275.493603  0.472814
# 25                    12.346339     64.952822      274.185462  0.502405
# 26                    12.668623     65.210672      274.592850  0.493063
# 27                    12.554054     65.482869      274.501559  0.522869
# 28                    12.530037     65.366172      279.007974  0.504519
# 29                    12.617507     64.754170      276.182493  0.491777
# 30                    12.445867     64.119813      267.291200  0.482667
# 31                    12.457654     64.835139      275.892688  0.508154
# 32                    12.469061     65.441475      276.716575  0.516022
# 33                    12.090909     64.892991      275.046921  0.513196
# 34                    12.453534     65.833317      277.506956  0.480801
# 35                    12.543631     65.317940      272.553930  0.508401
# 36                    12.398063     65.371689      278.805272  0.516945
# 37                    12.573797     64.986321      274.237968  0.487166
# 38                    12.415736     65.494157      273.353299  0.502030
# 39                    12.598096     64.710085      275.334744  0.493919
# 40                    12.293333     64.608907      270.393067  0.484800
# 41                    12.435792     65.594605      275.372357  0.527076
# 42                    12.439896     65.180394      276.898964  0.489119
# 43                    12.442834     65.601728      268.559850  0.513151
# 44                    12.626305     64.993779      268.826200  0.494781
# 45                    12.581281     64.860865      275.370553  0.494253
# 46                    12.631635     64.385303      272.113137  0.494906
# 47                    12.827829     65.032777      272.492149  0.499729
# 48                    12.474934     65.253889      274.326121  0.492876
# 49                    12.695254     64.625248      277.044768  0.480583
# 50                    12.577154     64.875546      277.224449  0.472445
# 51                    12.528771     65.164686      278.613271  0.499222
# 52                    12.132127     66.184095      276.735197  0.497259
# 53                    12.284433     65.212707      272.087599  0.510290
# 54                    12.289557     65.496086      274.594409  0.505274
# 55                    12.320000     65.317553      275.883158  0.501053
# 56                    12.417735     64.770208      274.477030  0.470085
# 57                    12.490216     64.227456      272.270340  0.502575
# 58                    12.551706     65.346119      272.614606  0.499467
# 59                    12.543050     65.435576      269.962656  0.524378
# 60                    12.557248     66.140457      274.873424  0.497374
# 61                    12.328444     64.835888      276.357255  0.490309
# 62                    12.562400     63.962957      280.753615  0.507231
# 63                    12.631308     65.666277      273.025747  0.476828
# 64                    12.489177     64.855898      270.156926  0.489719
# 65                    12.757229     64.633557      276.472995  0.499727
# 66                    12.773673     64.099802      277.949532  0.514048
# 67                    12.389321     65.614978      277.182981  0.503893
# 68                    12.454106     65.154933      275.083736  0.503489
# 69                    12.574268     64.703206      271.270921  0.504184
# 70                    12.564289     65.282207      275.071838  0.490370

# %%
plt.figure(figsize=(10,5))
plt.title("Average Subscription Length Vs Age",y=1.1,fontweight='bold')

fig=sns.lineplot(data=data_group,y=data_group["Subscription_Length_Months"],x=data_group.index,color='#DE3163')
fig.spines[['right','top']].set_visible(False)                                          # Removing the chart junk like boarders

# %%
plt.figure(figsize=(10,5))
plt.title("Monthly Bill Vs Age",y=1.1,fontweight='bold')

fig=sns.lineplot(data=data_group,y=data_group['Monthly_Bill'],x=data_group.index,color='Teal')
fig.spines[['right','top']].set_visible(False)                                          # Removing the chart junk like boarders

# %%
plt.figure(figsize=(10,5))
plt.title("Total usage (GB) Vs Age",y=1.1,fontweight='bold')

fig=sns.lineplot(data=data_group,y=data_group['Total_Usage_GB'],x=data_group.index,color='#191970')
fig.spines[['right','top']].set_visible(False)                                          # Removing the chart junk like boarders

# %%
data_manipulated=data.pivot_table(index=['Age','Location'],values=['Subscription_Length_Months','Monthly_Bill','Total_Usage_GB'],aggfunc=['mean','sum','max','min'])
data_manipulated
# Out:
#                         mean                                            \
#                 Monthly_Bill Subscription_Length_Months Total_Usage_GB
# Age Location
# 18  Chicago        66.528057                  12.772021     281.619171
#     Houston        64.665459                  12.832021     283.112861
#     Los Angeles    65.391734                  12.607046     276.742547
#     Miami          66.085153                  13.003067     275.604294
#     New York       65.387162                  11.663130     264.676393
# ...                      ...                        ...            ...
# 70  Chicago        65.728289                  12.687042     265.855746
#     Houston        63.827584                  12.329870     268.093506
#     Los Angeles    66.659739                  12.577023     272.817232
#     Miami          62.799431                  13.300813     285.661247
#     New York       67.325227                  11.933333     284.170667
#
#                          sum                                            \
#                 Monthly_Bill Subscription_Length_Months Total_Usage_GB
# Age Location
# 18  Chicago         25679.83                       4930         108705
#     Houston         24637.54                       4889         107866
#     Los Angeles     24129.55                       4652         102118
#     Miami           21543.76                       4239          89847
#     New York        24650.96                       4397          99783
# ...                      ...                        ...            ...
# 70  Chicago         26882.87                       5189         108735
#     Houston         24573.62                       4747         103216
#     Los Angeles     25530.68                       4817         104489
#     Miami           23172.99                       4908         105409
#     New York        25246.96                       4475         106564
#
#                          max                                            \
#                 Monthly_Bill Subscription_Length_Months Total_Usage_GB
# Age Location
# 18  Chicago            99.98                         24            500
#     Houston            99.71                         24            498
#     Los Angeles        99.90                         24            500
#     Miami              99.92                         24            499
#     New York           99.92                         24            499
# ...                      ...                        ...            ...
# 70  Chicago            99.74                         24            500
#     Houston            99.89                         24            499
#     Los Angeles        99.93                         24            498
#     Miami              99.96                         24            500
#     New York           99.92                         24            499
#
#                          min
#                 Monthly_Bill Subscription_Length_Months Total_Usage_GB
# Age Location
# 18  Chicago            30.53                          1             50
#     Houston            30.02                          1             50
#     Los Angeles        30.01                          1             50
#     Miami              30.47                          1             52
#     New York           30.19                          1             50
# ...                      ...                        ...            ...
# 70  Chicago            30.10                          1             50
#     Houston            30.05                          1             52
#     Los Angeles        30.04                          1             50
#     Miami              30.20                          1             56
#     New York           30.17                          1             51
#
# [265 rows x 12 columns]

# %%
data_group_age2=data.groupby(['Age','Gender','Location']).mean()
data_group_age2.drop(['Churn'],axis=1,inplace=True)

# %%
data_group_age2_reset=data_group_age2.reset_index()
data_group_age2
# Out:
#                         Subscription_Length_Months  Monthly_Bill  \
# Age Gender Location
# 18  Female Chicago                       13.156250     67.983177
#            Houston                       12.884615     66.542637
#            Los Angeles                   13.027027     65.804486
#            Miami                         13.450617     64.163333
#            New York                      11.583333     66.700000
# ...                                            ...           ...
# 70  Male   Chicago                       12.553299     65.271066
#            Houston                       12.711443     65.293582
#            Los Angeles                   12.527094     65.109015
#            Miami                         12.972376     60.826740
#            New York                      12.409091     67.066023
#
#                         Total_Usage_GB
# Age Gender Location
# 18  Female Chicago          284.328125
#            Houston          282.846154
#            Los Angeles      278.627027
#            Miami            278.438272
#            New York         265.171875
# ...                                ...
# 70  Male   Chicago          259.675127
#            Houston          264.796020
#            Los Angeles      279.842365
#            Miami            279.756906
#            New York         288.352273
#
# [530 rows x 3 columns]

# %%
sns.scatterplot(data=data_group_age2,x='Age',y='Subscription_Length_Months')
# Out:
# <Axes: xlabel='Age', ylabel='Subscription_Length_Months'>

# %%
sns.jointplot(data=data_group_age2,x='Age',y='Subscription_Length_Months',palette='hsv',kind='reg')

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=data_group_age2_reset,x='Age',y='Subscription_Length_Months',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Subscription_Length_Months'>

# %% [markdown]
# ### **2. Gender Column**

# %%
data['Gender'].value_counts()
# Out:
# Female    50216
# Male      49784
# Name: Gender, dtype: int64

# %% [markdown]
# **Univariation**

# %%
plt.figure(figsize=(10,2))
plot=sns.countplot(data=data,y='Gender',palette='magma',saturation=1)
title="Count Plot of Gender Column"
plot.set_title(f"{title}",fontsize=15,fontweight='bold',x=0.23,y=1.05)
plot.bar_label(plot.containers[0])
plot.spines[['right','top','bottom']].set_visible(False)                                # Removing the chart junk
plot.xaxis.set_visible(False)
plt.ylabel('Gender',fontweight='bold',fontsize=10)
plt.savefig(f'{title}')

# %%
plt.figure(figsize=(5,5))
sns.countplot(data=data,x='Gender',hue='Churn',palette='gist_rainbow_r',saturation=0.6)
plt.xlabel('Gender',fontweight='bold')
# Out:
# Text(0.5, 0, 'Gender')

# %% [markdown]
# **Bi-variation**

# %%
gender=pd.pivot_table(data=data,values='Churn',index='Gender').sort_values(by='Churn')
gender['Churn']=gender['Churn']*100
gender.style.bar(cmap='inferno',height=70,props="width:40em;")
# Out:
# <style type="text/css">
# #T_3d667_row0_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #fafda1 99.6%, transparent 99.6%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_3d667_row1_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #fcffa4 100.0%, transparent 100.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# </style>
# <table id="T_3d667" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d667_level0_col0" class="col_heading level0 col0" >Churn</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d667_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_3d667_row0_col0" class="data row0 col0" >49.673411</td>
#     </tr>
#     <tr>
#       <th id="T_3d667_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_3d667_row1_col0" class="data row1 col0" >49.885505</td>
#     </tr>
#   </tbody>
# </table>

# %%
gender.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
fig,axes=plt.subplots(1,2,figsize=(17,3))
plt.suptitle("Percentage of Churn in Male and Female",fontweight='bold',fontsize=20)

# Bar chart
axs=sns.barplot(data=gender,y=gender.index,x=gender['Churn'],ax=axes[0])
axs.bar_label(axs.containers[0],fmt='%.1f%%',fontweight='bold',padding=5)       # Setting bar labels with percentage of conversion
axes[0].spines[['right','top','bottom']].set_visible(False)                     # Removing the chart junk
axes[0].xaxis.set_visible(False)                                                # Hiding the x-axis
axs.set_ylabel("Job",fontweight='bold',fontsize=13)

# Pie chart
gender.plot(kind='pie',subplots=True,ax=axes[1],cmap="Paired")
plt.ylabel("")                                                                  # Removing the ylabel on pie chart

# Setting the legend location
plt.legend(loc='upper right',bbox_to_anchor=(1.7,0.9),title='Percentage')

# %%
fig,axes=plt.subplots(1,2,figsize=(20,3))
sup_title="Comparing the CountPlot with Percentage of Churn in Male and Female"
plt.suptitle(f"{sup_title}",fontweight='bold',fontsize=20,y=1.3)
fig.subplots_adjust(wspace=0.3)

# Bar Plot
bar_Plot=sns.barplot(data=gender,y=gender.index,x=gender['Churn'],ax=axes[1],palette='cool')
bar_Plot.bar_label(bar_Plot.containers[0],fmt='%.1f%%',padding=-35,color='white',fontweight='bold')             # Setting bar labels with percentage of conversion
bar_Plot.set_title("Percentage of Churn in Male and Female",fontsize=15,fontweight='bold',x=0.4,y=1.05)         # Setting the title for subplot
bar_Plot.set_ylabel("Gender",fontweight='bold',fontsize=13)                                                     # Setting the ylabel
axes[1].spines[['right','top','bottom']].set_visible(False)                                                     # Removing the chart junk
axes[1].xaxis.set_visible(False)                                                                                # Hiding the x-axis

# Count Plot
cnt_Plot=sns.countplot(data=data,y='Gender',palette='icefire',ax=axes[0])
cnt_Plot.bar_label(cnt_Plot.containers[0],fontweight='bold')                                                    # Setting bar labels with count
cnt_Plot.set_title("Count Plot of Gender Column",fontsize=15,fontweight='bold',x=0.25,y=1.05)                   # Setting the title for subplot
cnt_Plot.set_ylabel("Gender",fontweight='bold',fontsize=13)                                                     # Setting the ylabel
axes[0].spines[['right','top','bottom']].set_visible(False)                                                     # Removing the chart junk
axes[0].xaxis.set_visible(False)                                                                                # Hiding the x-axis

# %%
plt.figure(figsize=(12,3))
sns.heatmap(data=gender,annot=True,cmap='viridis',cbar_kws={'label':"Percentage of Conversion"}).figure.axes[-1].yaxis.label.set_size(15)
plt.title("Heatmap showing Rate of Churn in Male and Female in Percentages",fontsize=20,fontweight='bold',pad=25)
plt.xlabel("Percentage",fontsize=12,fontweight='bold',color='green')
plt.ylabel("Gender",fontsize=12,labelpad=20,fontweight='bold',color='green')
plt.xticks([])
# Out:
# ([], [])

# %% [markdown]
# From the above plots, it is evident that both male and female have same customer churn percentage.

# %% [markdown]
# **Multi-variation**

# %%
gender_N_location=data.pivot_table(index='Gender',columns='Location',values='Churn')
gender_N_location
# Out:
# Location   Chicago   Houston  Los Angeles     Miami  New York
# Gender
# Female    0.497908  0.491948     0.488356  0.506046  0.499400
# Male      0.498690  0.490256     0.497688  0.499950  0.508001

# %%
gender_N_location=gender_N_location.apply(lambda x:x*100)
gender_N_location
# Out:
# Location    Chicago    Houston  Los Angeles      Miami   New York
# Gender
# Female    49.790753  49.194758    48.835596  50.604559  49.940012
# Male      49.868978  49.025591    49.768844  49.994970  50.800122

# %%
plt.figure(figsize=(9,5))

sns.heatmap(data=gender_N_location,annot=True,cmap='icefire',cbar_kws={'label':"Percentage of Churn"}).figure.axes[-1].yaxis.label.set_size(20)
plt.title("Heatmap showing Rate of Churn with various 'Locations & Gender' in Percentages",fontsize=20,fontweight='bold',pad=25)

plt.xlabel("Location",fontsize=15,fontweight='bold',labelpad=5)
plt.xticks(fontsize=13,rotation=45,ha='right')
plt.ylabel("Gender",fontsize=15,fontweight='bold',labelpad=20)
plt.yticks(fontsize=13)
# Out:
# (array([0.5, 1.5]), [Text(0, 0.5, 'Female'), Text(0, 1.5, 'Male')])

# %%
data_group_location=data.groupby(['Location','Gender']).mean()
data_group_location
# Out:
#                           Age  Subscription_Length_Months  Monthly_Bill  \
# Location    Gender
# Chicago     Female  44.111798                   12.491431     64.885483
#             Male    44.314755                   12.549788     64.752471
# Houston     Female  44.156447                   12.449735     65.207742
#             Male    44.007972                   12.479429     65.049390
# Los Angeles Female  43.688435                   12.508275     64.963713
#             Male    44.064824                   12.437286     65.424280
# Miami       Female  44.233598                   12.579286     64.837054
#             Male    43.883714                   12.553164     65.067215
# New York    Female  43.882224                   12.409718     65.148906
#             Male    43.927428                   12.441749     65.201562
#
#                     Total_Usage_GB     Churn
# Location    Gender
# Chicago     Female      274.950379  0.497908
#             Male        273.598166  0.498690
# Houston     Female      271.985596  0.491948
#             Male        275.662402  0.490256
# Los Angeles Female      275.544743  0.488356
#             Male        272.406633  0.497688
# Miami       Female      275.484341  0.506046
#             Male        273.979982  0.499950
# New York    Female      274.883823  0.499400
#             Male        275.397411  0.508001

# %%
data_group_location.drop(['Churn'],axis=1,inplace=True)

# %%
data_group_location
# Out:
#                           Age  Subscription_Length_Months  Monthly_Bill  \
# Location    Gender
# Chicago     Female  44.111798                   12.491431     64.885483
#             Male    44.314755                   12.549788     64.752471
# Houston     Female  44.156447                   12.449735     65.207742
#             Male    44.007972                   12.479429     65.049390
# Los Angeles Female  43.688435                   12.508275     64.963713
#             Male    44.064824                   12.437286     65.424280
# Miami       Female  44.233598                   12.579286     64.837054
#             Male    43.883714                   12.553164     65.067215
# New York    Female  43.882224                   12.409718     65.148906
#             Male    43.927428                   12.441749     65.201562
#
#                     Total_Usage_GB
# Location    Gender
# Chicago     Female      274.950379
#             Male        273.598166
# Houston     Female      271.985596
#             Male        275.662402
# Los Angeles Female      275.544743
#             Male        272.406633
# Miami       Female      275.484341
#             Male        273.979982
# New York    Female      274.883823
#             Male        275.397411

# %%
data_group_location_reset = data_group_location.reset_index()

# %%
data_group_location_reset
# Out:
#       Location  Gender        Age  Subscription_Length_Months  Monthly_Bill  \
# 0      Chicago  Female  44.111798                   12.491431     64.885483
# 1      Chicago    Male  44.314755                   12.549788     64.752471
# 2      Houston  Female  44.156447                   12.449735     65.207742
# 3      Houston    Male  44.007972                   12.479429     65.049390
# 4  Los Angeles  Female  43.688435                   12.508275     64.963713
# 5  Los Angeles    Male  44.064824                   12.437286     65.424280
# 6        Miami  Female  44.233598                   12.579286     64.837054
# 7        Miami    Male  43.883714                   12.553164     65.067215
# 8     New York  Female  43.882224                   12.409718     65.148906
# 9     New York    Male  43.927428                   12.441749     65.201562
#
#    Total_Usage_GB
# 0      274.950379
# 1      273.598166
# 2      271.985596
# 3      275.662402
# 4      275.544743
# 5      272.406633
# 6      275.484341
# 7      273.979982
# 8      274.883823
# 9      275.397411

# %%
data_group_location.index
# Out:
# MultiIndex([(    'Chicago', 'Female'),
#             (    'Chicago',   'Male'),
#             (    'Houston', 'Female'),
#             (    'Houston',   'Male'),
#             ('Los Angeles', 'Female'),
#             ('Los Angeles',   'Male'),
#             (      'Miami', 'Female'),
#             (      'Miami',   'Male'),
#             (   'New York', 'Female'),
#             (   'New York',   'Male')],
#            names=['Location', 'Gender'])

# %% [markdown]
# ### **Methods**

# %%
def continuous_variables(column):
  column=str(column)
  fig,axes=plt.subplots(1,2,figsize=(25,7))

  sns.histplot(data=data,x=data[column],hue='Churn',palette='seismic_r',binwidth=2,kde=True,ax=axes[0]).set_title(f"Histogram of {column} Column",fontweight='bold',fontsize=20)
  sns.histplot(data=data,x=data[column],hue='Churn',palette='mako',binwidth=2,kde=True,ax=axes[1],multiple='fill',stat='probability').set_title(f"Histogram of Probability of Churn in {column}",fontweight='bold',fontsize=20 )

# %%
def line(data,x,y):
  plt.figure(figsize=(10,5))
  plt.title("Average Subscription Length Vs Age",y=1.1,fontweight='bold')

  fig=sns.lineplot(data=data,y=y,x=data.index,color='#DE3163')
  fig.spines[['right','top']].set_visible(False)                                          # Removing the chart junk like boarders

# %% [markdown]
# ### **3. Location**

# %%
data['Location'].value_counts()
# Out:
# Houston        11875
# New York       11719
# Miami          11718
# Los Angeles    11705
# Chicago        11651
# Name: Location, dtype: int64

# %%
plt.figure(figsize=(10,2))
plot=sns.countplot(data=data,y='Location',palette='magma',saturation=1)
title="Count Plot of Location Column"
plot.set_title(f"{title}",fontsize=15,fontweight='bold',x=0.23,y=1.05)
plot.bar_label(plot.containers[0])
plot.spines[['right','top','bottom']].set_visible(False)                                # Removing the chart junk
plot.xaxis.set_visible(False)
plt.ylabel('City',fontweight='bold',fontsize=10)
# Out:
# Text(0, 0.5, 'City')

# %%
col=['#AAFF00','#000080']
col
# Out:
# ['#AAFF00', '#000080']

# %%
plt.figure(figsize=(10,5))

plot=sns.countplot(data=data,x='Location',hue='Churn',palette=col,saturation=1.0)
plt.xlabel('Location',fontweight='bold')

for container in plot.containers:
    plot.bar_label(container)

plot.spines[['right','top']].set_visible(False)
plt.legend(title='Churn', loc='upper right',bbox_to_anchor=(1.1,1.0))
plt.show()

# %%
location=pd.pivot_table(data=data,values='Churn',index='Location').sort_values(by='Churn')
location['Churn']=location['Churn']*100
# location.reset_index(inplace=True)

location.style.bar(cmap='inferno',height=70,props="width:40em;")
# Out:
# <style type="text/css">
# #T_0b549_row0_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #f4f88e 97.4%, transparent 97.4%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_0b549_row1_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #f8fb9a 98.8%, transparent 98.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_0b549_row2_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #f9fc9d 98.9%, transparent 98.9%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_0b549_row3_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #fafda1 99.3%, transparent 99.3%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_0b549_row4_col0 {
#   width: 40em;
#   background: linear-gradient(90deg, #fcffa4 100.0%, transparent 100.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# </style>
# <table id="T_0b549" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b549_level0_col0" class="col_heading level0 col0" >Churn</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Location</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b549_level0_row0" class="row_heading level0 row0" >Houston</th>
#       <td id="T_0b549_row0_col0" class="data row0 col0" >49.120000</td>
#     </tr>
#     <tr>
#       <th id="T_0b549_level0_row1" class="row_heading level0 row1" >Los Angeles</th>
#       <td id="T_0b549_row1_col0" class="data row1 col0" >49.807774</td>
#     </tr>
#     <tr>
#       <th id="T_0b549_level0_row2" class="row_heading level0 row2" >Chicago</th>
#       <td id="T_0b549_row2_col0" class="data row2 col0" >49.884130</td>
#     </tr>
#     <tr>
#       <th id="T_0b549_level0_row3" class="row_heading level0 row3" >Miami</th>
#       <td id="T_0b549_row3_col0" class="data row3 col0" >50.068271</td>
#     </tr>
#     <tr>
#       <th id="T_0b549_level0_row4" class="row_heading level0 row4" >New York</th>
#       <td id="T_0b549_row4_col0" class="data row4 col0" >50.430924</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig,axes=plt.subplots(1,2,figsize=(17,3))
plt.suptitle("Percentage of Churn in Location",fontweight='bold',fontsize=20)

# Bar chart
axs=sns.barplot(data=location,y=location.index,x=location['Churn'],ax=axes[0])
axs.bar_label(axs.containers[0],fmt='%.1f%%',fontweight='bold',padding=5)       # Setting bar labels with percentage of conversion
axes[0].spines[['right','top','bottom']].set_visible(False)                     # Removing the chart junk
axes[0].xaxis.set_visible(False)                                                # Hiding the x-axis
axs.set_ylabel("Job",fontweight='bold',fontsize=13)

# Pie chart
location.plot(kind='pie',subplots=True,ax=axes[1],cmap="Paired")
plt.ylabel("")                                                                  # Removing the ylabel on pie chart

# Setting the legend location
plt.legend(loc='upper right',bbox_to_anchor=(1.8,0.9),title='Percentage')

# %%
fig,axes=plt.subplots(1,2,figsize=(20,3))
sup_title="Comparing the CountPlot with Percentage of Churn in Location"
plt.suptitle(f"{sup_title}",fontweight='bold',fontsize=20,y=1.3)
fig.subplots_adjust(wspace=0.3)

# Bar Plot
bar_Plot=sns.barplot(data=location,y=location.index,x=location['Churn'],ax=axes[1],palette='cool')
bar_Plot.bar_label(bar_Plot.containers[0],fmt='%.1f%%',padding=-35,color='white',fontweight='bold')             # Setting bar labels with percentage of conversion
bar_Plot.set_title("Percentage of Churn in Male and Female",fontsize=15,fontweight='bold',x=0.4,y=1.05)         # Setting the title for subplot
bar_Plot.set_ylabel("Location",fontweight='bold',fontsize=13)                                                     # Setting the ylabel
axes[1].spines[['right','top','bottom']].set_visible(False)                                                     # Removing the chart junk
axes[1].xaxis.set_visible(False)                                                                                # Hiding the x-axis

# Count Plot
cnt_Plot=sns.countplot(data=data,y='Location',palette='icefire',ax=axes[0])
cnt_Plot.bar_label(cnt_Plot.containers[0],fontweight='bold')                                                    # Setting bar labels with count
cnt_Plot.set_title("Count Plot of Location Column",fontsize=15,fontweight='bold',x=0.25,y=1.05)                   # Setting the title for subplot
cnt_Plot.set_ylabel("Location",fontweight='bold',fontsize=13)                                                     # Setting the ylabel
axes[0].spines[['right','top','bottom']].set_visible(False)                                                     # Removing the chart junk
axes[0].xaxis.set_visible(False)                                                                                # Hiding the x-axis

# %%
plt.figure(figsize=(12,3))
sns.heatmap(data=location,annot=True,cmap='viridis',fmt=".4f",cbar_kws={'label':"Percentage of Conversion"}).figure.axes[-1].yaxis.label.set_size(15)
plt.title("Heatmap showing Rate of Churn in Location in Percentages",fontsize=20,fontweight='bold',pad=25)
plt.xlabel("Percentage",fontsize=12,fontweight='bold',color='green')
plt.ylabel("Location",fontsize=12,labelpad=20,fontweight='bold',color='green')
plt.xticks([])
# Out:
# ([], [])

# %% [markdown]
# ### **4.Subscription_Length_Months**

# %%
data['Subscription_Length_Months'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(9,3))
sns.boxplot(data=data,x='Subscription_Length_Months',palette='hsv')
# Out:
# <Axes: xlabel='Subscription_Length_Months'>

# %% [markdown]
# There are no outliers

# %%
continuous_variables('Subscription_Length_Months')

# %%
sns.scatterplot(data=data,y='Monthly_Bill',x='Subscription_Length_Months',palette='rocket',hue='Churn')
# Out:
# <Axes: xlabel='Subscription_Length_Months', ylabel='Monthly_Bill'>

# %%
sns.scatterplot(data=data,y='Total_Usage_GB',x='Subscription_Length_Months',palette='rocket',hue='Churn')
# Out:
# <Axes: xlabel='Subscription_Length_Months', ylabel='Total_Usage_GB'>

# %%
sns.jointplot(data=data,y='Monthly_Bill',x='Subscription_Length_Months',palette='hsv',hue='Churn',kind='kde')

# %%
data_group_sub_months=data.groupby('Subscription_Length_Months').mean()
data_group_sub_months.reset_index(inplace=True)
# Out:
# <ipython-input-58-8a0fb6f2cedb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_group_sub_months=data.groupby('Subscription_Length_Months').mean()

# %%
data_group_sub_months
# Out:
#     Subscription_Length_Months        Age  Monthly_Bill  Total_Usage_GB  \
# 0                            1  44.005887     65.422074      273.166000
# 1                            2  44.217124     65.327297      273.280038
# 2                            3  44.066973     65.093641      274.525387
# 3                            4  43.822108     65.084231      272.292338
# 4                            5  43.481899     65.105649      276.584752
# 5                            6  44.075765     65.293227      278.617830
# 6                            7  44.058418     65.025782      274.665638
# 7                            8  43.770823     64.936956      274.700925
# 8                            9  43.884373     65.374023      275.409289
# 9                           10  44.237051     64.967851      274.853047
# 10                          11  44.061667     64.755667      271.516429
# 11                          12  44.248375     65.547543      274.966546
# 12                          13  43.760953     64.652335      276.897448
# 13                          14  44.189176     65.076219      275.158557
# 14                          15  44.097283     65.038862      274.824842
# 15                          16  43.698510     65.155867      274.454008
# 16                          17  43.916831     65.200234      274.236467
# 17                          18  44.475426     64.842321      272.386718
# 18                          19  44.138578     64.721812      275.236727
# 19                          20  44.182896     64.618606      275.353707
# 20                          21  44.158161     65.352845      273.246269
# 21                          22  43.927349     64.680516      269.862667
# 22                          23  43.960568     65.016556      274.382562
# 23                          24  44.203258     64.998293      274.946268
#
#        Churn
# 0   0.503414
# 1   0.498817
# 2   0.504352
# 3   0.492435
# 4   0.483337
# 5   0.487572
# 6   0.502256
# 7   0.496834
# 8   0.492743
# 9   0.500361
# 10  0.498095
# 11  0.501805
# 12  0.507222
# 13  0.492048
# 14  0.487385
# 15  0.503429
# 16  0.497293
# 17  0.496763
# 18  0.504627
# 19  0.496165
# 20  0.490611
# 21  0.501289
# 22  0.501592
# 23  0.506443

# %%
plt.figure(figsize=(10,5))
plt.title("Average Monthly Bill Vs Subscription Length",y=1.1,fontweight='bold')

fig=sns.lineplot(data=data_group_sub_months,y=data_group_sub_months["Monthly_Bill"],x=data_group_sub_months.Subscription_Length_Months,color='#DE3163')
fig.spines[['right','top']].set_visible(False)                                          # Removing the chart junk like boarders

# %%
plt.figure(figsize=(10,5))
plt.title("Average Total_Usage_GB Vs Subscription Length",y=1.1,fontweight='bold')

fig=sns.lineplot(data=data_group_sub_months,y=data_group_sub_months["Total_Usage_GB"],x=data_group_sub_months.Subscription_Length_Months,color='#DE3163')
fig.spines[['right','top']].set_visible(False)                                          # Removing the chart junk like boarders

# %%
sns.regplot(data=data_group_sub_months,x='Monthly_Bill',y='Subscription_Length_Months')
# Out:
# <Axes: xlabel='Monthly_Bill', ylabel='Subscription_Length_Months'>

# %%
sns.jointplot(data=data_group_sub_months,x='Monthly_Bill',y='Subscription_Length_Months',palette='hsv',kind='reg')

# %%
sns.jointplot(data=data_group_sub_months,x='Total_Usage_GB',y='Subscription_Length_Months',palette='hsv',kind='reg')

# %%
sns.jointplot(data=data_group_sub_months,y='Monthly_Bill',x='Subscription_Length_Months',palette='rocket',kind='kde',fill=True)

# %%
sns.jointplot(data=data_group_sub_months,y='Total_Usage_GB',x='Subscription_Length_Months',palette='rocket',kind='kde',fill=True)

# %%
data_group_sub_months[['Monthly_Bill','Subscription_Length_Months']].corr()
# Out:
#                             Monthly_Bill  Subscription_Length_Months
# Monthly_Bill                    1.000000                   -0.421691
# Subscription_Length_Months     -0.421691                    1.000000

# %%
data_group_sub_months[['Subscription_Length_Months','Total_Usage_GB']].corr()
# Out:
#                             Subscription_Length_Months  Total_Usage_GB
# Subscription_Length_Months                    1.000000       -0.160188
# Total_Usage_GB                               -0.160188        1.000000
